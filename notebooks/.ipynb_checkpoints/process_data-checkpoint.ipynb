# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import quandl

# %% [markdown]
# ## Get data from Quandl

# %%
apl_stock=quandl.get('WIKI/AAPL', start_date="2014-01-01", end_date="2019-06-20", )
msf_stock=quandl.get('WIKI/MSFT', start_date="2014-01-01", end_date="2019-06-20")
apl_open = apl_stock["Open"].values
apl_close = apl_stock["Close"].values
msf_open = msf_stock["Open"].values
msf_close = msf_stock["Close"].values

# %%
msf_stock.head()
# Out:
#               Open   High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
# Date
# 2014-01-02  37.350  37.40  37.10  37.16  30632200.0          0.0          1.0
# 2014-01-03  37.200  37.22  36.60  36.91  31134800.0          0.0          1.0
# 2014-01-06  36.850  36.89  36.11  36.13  43603700.0          0.0          1.0
# 2014-01-07  36.325  36.49  36.21  36.41  35802800.0          0.0          1.0
# 2014-01-08  36.000  36.14  35.58  35.76  59971700.0          0.0          1.0
#
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# Date
# 2014-01-02  33.704254  33.749373  33.478656   33.532800   30632200.0
# 2014-01-03  33.568895  33.586943  33.027461   33.307202   31134800.0
# 2014-01-06  33.253059  33.289154  32.585290   32.603338   43603700.0
# 2014-01-07  32.779304  32.928198  32.675529   32.856007   35802800.0
# 2014-01-08  32.486028  32.612362  32.107024   32.269454   59971700.0

# %% [markdown]
# ## Examine data

# %%
def plot_data(values, title):
    plt.plot(range(0, len(values)), values)
    plt.title(title)
    plt.grid()
    plt.show()

# %%
plot_data(msf_open, 'msf_open original')

# %%
plot_data(apl_open, 'apl_open original')

# %% [markdown]
# ## What happened - stock split

# %% [markdown]
# Problem:  9 June 2014: AAPL stock was split in the ratio of 1:7.
#
# Solution: divide everything before element 108 in the stock array by 7 to correct for this.

# %%
apl_open[:108] /= 7

# %%
apl_close[:108] /= 7

# %%
plot_data(apl_open, 'apl_open adjusted for stock split')

# %% [markdown]
# ## Remove general upwards trend.
#
# • De-trend the data.
#
# • Otherwise can't expect model to learn to trade MSFT and AAPL when they are on different scales.
#
# • Also want the model to learn the fundamentals of the stock signal - buy if it's going to rise.
#
# • Without removing trend, the model might simply learn to hold - i.e. buy at the start and hold until the end in upward trends. WHile beneficial, we want more from the model.

# %%
from scipy import signal

# %%
# Signal processing module - fit linear LSQ model to data and subtract it.
msf_open = signal.detrend(msf_open)
msf_close = signal.detrend(msf_close)

plot_data(msf_open, 'msf_open detrended')

# %%
apl_open = signal.detrend(apl_open)
apl_close = signal.detrend(apl_close)

plot_data(apl_open, 'apl_open detrended')

# %% [markdown]
# ## Remove negative values
#
# • Doesn't make sense to buy a share at a negative value.
#
# • The model will learn to maximize reward anyway --> can simply shift values up by a constant number to ensure strictly positive.

# %%
print(apl_open.min())
print(apl_close.min())
print(msf_open.min())
print(msf_close.min())
# Out:
# -34.32168425572115
# -34.447411978136344
# -11.365775305682883
# -11.834602851532022

# %% [markdown]
# Choose +35

# %%
apl_open += 35.
apl_close += 35.
msf_open += 35.
msf_close += 35.

# %% [markdown]
# ## Save transformed data

# %%
import pickle
with open("apl_msf_open_close.pkl", "wb+") as f:
    pickle.dump({"ao":apl_open, "ac": apl_close, "mo": msf_open, "mc": msf_close}, f)

# %% [markdown]
# ## If the data's already saved, skip the above and load it here instead

# %%
import pickle
with open("apl_msf_open_close.pkl", "rb") as f:
    d = pickle.load(f)
    
apl_open = d["ao"]
apl_close = d["ac"]
msf_open = d["mo"]
msf_close = d["mc"]

# %%
plot_data(apl_open, 'apl_open reloaded')

# %% [markdown]
# # Build the environment
#
# * For starting cash, we can't use a dollar value because of the transformed data. After shifting earlier, we know the mean of each opening price should be 35, so I'm starting the agent off with enough cash to buy ~2.5 shares.
# * This starting cash is the mean starting cash; it can be randomized by altering the std parameter
# * action space = 0 buy apple, 1 sell apple, 2 do nothing, 3 buy msft, 4 sell msft, quantity. eg. [0, 100]
# * obs space: apl shares, msft shares, cash in bank [2], today apl open [3], today msf open [4], portfolio value [5], 5 day window [6apl, 7msf] = 8
# * If bot gets to the end with more than one of each share, we give it a bonus for having a diversified portfolio!
# * Buys and sells attract a 10% brokerage fee

# %%
class TradingEnvironment():

    def __init__(self, starting_cash_mean=200., max_stride=5, series_length=208, starting_point=1, randomize_cash_std=0, \
                 starting_shares_mean=0., randomize_shares_std=0., inaction_penalty=0.):
        self.starting_shares_mean = starting_shares_mean
        self.randomize_shares_std = randomize_shares_std
        self.starting_cash_mean = starting_cash_mean
        self.randomize_cash_std = randomize_cash_std
        
        # self.state = torch.FloatTensor(torch.zeros(8)).cuda()
        self.state = torch.FloatTensor(torch.zeros(8))
        
        self.starting_cash = max(int(np.random.normal(self.starting_cash_mean, self.randomize_cash_std)), 0.)
        
        self.series_length = series_length
        self.starting_point = starting_point
        self.cur_timestep = self.starting_point
        
        self.state[0] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.state[1] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.starting_portfolio_value = self.portfolio_value()
        self.state[2] = self.starting_cash
        self.state[3] = apl_open[self.cur_timestep]
        self.state[4] = msf_open[self.cur_timestep]
        self.state[5] = self.starting_portfolio_value
        self.state[6] = self.five_day_window()[0]
        self.state[7] = self.five_day_window()[1]
        
        self.max_stride = max_stride
        self.stride = self.max_stride # no longer varying it
        
        self.done = False
        self.diversification_bonus = 1.
        self.inaction_penalty = inaction_penalty
    
    def portfolio_value(self):
        return (self.state[0] * apl_close[self.cur_timestep]) + (self.state[1] * msf_close[self.cur_timestep]) + self.state[2]
    
    def next_opening_price(self):
        step = self.cur_timestep + self.stride
        return [apl_open[step], msf_open[step]]
    
    def five_day_window(self):
        step = self.cur_timestep
        if step < 5:
            return [apl_open[0], msf_open[0]]
        apl5 = apl_open[step-5:step].mean()
        msf5 = msf_open[step-5:step].mean()
        return [apl5, msf5]
    
    def step(self, action):
        action = [action, 1.]
        cur_timestep = self.cur_timestep
        ts_left = self.series_length - (cur_timestep - self.starting_point)
        retval = None
        cur_value = self.portfolio_value()
        gain = cur_value - self.starting_portfolio_value
        
        if cur_timestep >= self.starting_point + (self.series_length * self.stride):
            new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
            self.state = new_state
            bonus = 0.
            if self.state[0] > 0 and self.state[1] > 0:
                bonus = self.diversification_bonus
            return new_state, cur_value + bonus + gain, True, { "msg": "done"}
        
        if action[0] == 2:
            new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                    cur_value, *self.five_day_window()]
            self.state = new_state
            retval = new_state, -self.inaction_penalty-ts_left +gain, False, { "msg": "nothing" }
            
        if action[0] == 0:
            if action[1] * apl_open[cur_timestep] > self.state[2]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, -ts_left+gain/2, True, { "msg": "bankrupted self"}
            else:
                apl_shares = self.state[0] + action[1]
                cash_spent = action[1] * apl_open[cur_timestep] * 1.1
                new_state = [apl_shares, self.state[1], self.state[2] - cash_spent, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "bought AAPL"}
                
        if action[0] == 3:
            if action[1] * msf_open[cur_timestep] > self.state[2]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval =  new_state, -ts_left+gain/2, True, { "msg": "bankrupted self"}
            else:
                msf_shares = self.state[1] + action[1]
                cash_spent = action[1] * msf_open[cur_timestep] * 1.1
                new_state = [self.state[0], msf_shares, self.state[2] - cash_spent, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "bought MSFT"}
        

        if action[0] == 1:
            if action[1] > self.state[0]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, -ts_left+gain/2, True, { "msg": "sold more than have"}
            else:
                apl_shares = self.state[0] - action[1]
                cash_gained = action[1] * apl_open[cur_timestep] * 0.9
                new_state = [apl_shares, self.state[1], self.state[2] + cash_gained, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "sold AAPL"}
                
        if action[0] == 4:
            if action[1] > self.state[1]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, -ts_left+gain/2, True, { "msg": "sold more than have"}
            else:
                msf_shares = self.state[1] - action[1]
                cash_gained = action[1] * msf_open[cur_timestep] * 0.9
                new_state = [self.state[0], msf_shares, self.state[2] + cash_gained, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "sold MSFT"}
                
        self.cur_timestep += self.stride
        return retval
    
    def reset(self):
        # self.state = torch.FloatTensor(torch.zeros(8)).cuda()
        self.state = torch.FloatTensor(torch.zeros(8))
        self.starting_cash = max(int(np.random.normal(self.starting_cash_mean, self.randomize_cash_std)), 0.)
        self.cur_timestep = self.starting_point
        self.state[0] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.state[1] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.state[2] = self.starting_cash
        self.state[3] = apl_open[self.cur_timestep]
        self.state[4] = msf_open[self.cur_timestep]
        self.starting_portfolio_value = self.portfolio_value()
        self.state[5] = self.starting_portfolio_value
        self.state[6] = self.five_day_window()[0]
        self.state[7] = self.five_day_window()[1]       
        self.done = False
        return self.state

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.input_layer = nn.Linear(8, 128)
        self.hidden_1 = nn.Linear(128, 128)
        self.hidden_2 = nn.Linear(32,31)
        # self.hidden_state = torch.tensor(torch.zeros(2,1,32)).cuda()
        self.hidden_state = torch.tensor(torch.zeros(2,1,32))
        self.rnn = nn.GRU(128, 32, 2)
        self.action_head = nn.Linear(31, 5)
        self.value_head = nn.Linear(31, 1)
        self.saved_actions = []
        self.rewards = []

    def reset_hidden(self):
        # self.hidden_state = torch.tensor(torch.zeros(2,1,32)).cuda()
        self.hidden_state = torch.tensor(torch.zeros(2,1,32))
        
    def forward(self, x):
        # x = torch.tensor(x).cuda()
        x = torch.tensor(x)
        x = torch.sigmoid(self.input_layer(x))
        x = torch.tanh(self.hidden_1(x))
        x, self.hidden_state = self.rnn(x.view(1,-1,128), self.hidden_state.data)
        x = F.relu(self.hidden_2(x.squeeze()))
        action_scores = self.action_head(x)
        state_values = self.value_head(x)
        return F.softmax(action_scores, dim=-1), state_values
    
    def act(self, state):
        probs, state_value = self.forward(state)
        m = Categorical(probs)
        action = m.sample()
        # if action == 1 and env.state[0] < 1: action = torch.LongTensor([2]).squeeze().cuda()
        # if action == 4 and env.state[1] < 1: action = torch.LongTensor([2]).squeeze().cuda()
        if action == 1 and env.state[0] < 1: action = torch.LongTensor([2]).squeeze()
        if action == 4 and env.state[1] < 1: action = torch.LongTensor([2]).squeeze()
        self.saved_actions.append((m.log_prob(action), state_value))
        return action.item()

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)
# model = Policy().cuda()
model = Policy()
optimizer = optim.Adam(model.parameters(), lr=3e-4)
# Out:
# /Users/joe/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
env.reset()
# In case you're running this a second time with the same model, delete the gradients
del model.rewards[:]
del model.saved_actions[:]

gamma = 0.9
log_interval = 60

def finish_episode():
    R = 0
    saved_actions = model.saved_actions
    policy_losses = []
    value_losses = []
    rewards = []
    for r in model.rewards[::-1]:
        R = r + (gamma * R)
        rewards.insert(0, R)
    rewards = torch.tensor(rewards)
    
    epsilon = (torch.rand(1) / 1e4) - 5e-5
    # With different architectures, I found the following standardization step sometimes
    # helpful, sometimes unhelpful.
    # rewards = (rewards - rewards.mean()) / (rewards.std(unbiased=False) + epsilon)
    # Alternatively, comment it out and use the following line instead:
    rewards += epsilon
    
    for (log_prob, value), r in zip(saved_actions, rewards):
        # reward = torch.tensor(r - value.item()).cuda()
        reward = torch.tensor(r - value.item())
        policy_losses.append(-log_prob * reward)
        # value_losses.append(F.smooth_l1_loss(value, torch.tensor([r]).cuda()))
        value_losses.append(F.smooth_l1_loss(value, torch.tensor([r])))
        
    optimizer.zero_grad()
    loss = torch.stack(policy_losses).sum() + torch.stack(value_losses).sum()
    loss = torch.clamp(loss, -1e-5, 1e5)
    loss.backward()
    optimizer.step()
    del model.rewards[:]
    del model.saved_actions[:]

running_reward = 0
for episode in range(0, 4000):
    state = env.reset()
    reward = 0
    done = False
    msg = None
    while not done:
        action = model.act(state)
        state, reward, done, msg = env.step(action)
        model.rewards.append(reward)
        if done:
            break
    running_reward = running_reward * (1 - 1/log_interval) + reward * (1/log_interval)
    finish_episode()
    # Resetting the hidden state seems unnecessary - it's effectively random from the previous
    # episode anyway, more random than a bunch of zeros.
    # model.reset_hidden()
    if msg["msg"] == "done" and env.portfolio_value() > env.starting_portfolio_value * 1.1 and running_reward > 500:
        print("Early Stopping: " + str(int(reward)))
        break
    if episode % log_interval == 0:
        print("""Episode {}: started at {:.1f}, finished at {:.1f} because {} @ t={}, \
last reward {:.1f}, running reward {:.1f}""".format(episode, env.starting_portfolio_value, \
              env.portfolio_value(), msg["msg"], env.cur_timestep, reward, running_reward))
# Out:
# /Users/joe/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /Users/joe/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Episode 0: started at 7174.8, finished at 6500.8 because bankrupted self @ t=473, last reward 62.7, running reward 1.0
# Early Stopping: 10199

# %% [markdown]
# ## Let's see how it does in practice, on the training data

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)

total_rewards = 0
total_profits = 0
failed_goes = 0
num_goes = 50

for j in range(num_goes):
    env.reset()
    reward_this_go = -1e8
    for i in range(0,env.series_length + 1):
        action = model.act(env.state)
        next_state, reward, done, msg = env.step(action)
        if msg["msg"] == "done":
            reward_this_go = env.portfolio_value()
            break
        if done:
            break
    total_profits += (env.portfolio_value() - env.starting_portfolio_value) / env.starting_portfolio_value
    if reward_this_go == -1e8:
        failed_goes += 1
    else:
        total_rewards += reward_this_go

if failed_goes == num_goes:
    print("Failed all")
else:
    print("Failed goes: {} / {}, Avg Rewards per successful game: {}".format(failed_goes, num_goes, total_rewards / (num_goes - failed_goes)))
    print("Avg % profit per game: {}".format(total_profits / num_goes))
    print("Avg % profit per finished game: {}".format(total_profits / (num_goes - failed_goes)))
# Out:
# /Users/joe/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Failed goes: 22 / 50, Avg Rewards per successful game: 9627.291015625
# Avg % profit per game: 0.11985281109809875
# Avg % profit per finished game: 0.21402287483215332

# %% [markdown]
# ## And here's how a sample trading run might look

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)
env.reset()
print("starting portfolio value {}".format(env.portfolio_value()))
for i in range(0,env.series_length + 1):
    action = model.act(env.state)
    next_state, reward, done, msg = env.step(action)
    if msg["msg"] == 'bankrupted self':
        print('bankrupted self by 1')
        break
    if msg["msg"] == 'sold more than have':
        print('sold more than have by 1')
        break
    print("{}, have {} aapl and {} msft and {} cash".format(msg["msg"], next_state[0], next_state[1], next_state[2]))
    if msg["msg"] == "done":
        print(next_state, reward)
        print("total portfolio value {}".format(env.portfolio_value()))
        break
# Out:
# starting portfolio value 8378.8935546875
# nothing, have 102.0 aapl and 107.0 msft and 1071.0 cash
# nothing, have 102.0 aapl and 107.0 msft and 1071.0 cash
# bought AAPL, have 103.0 aapl and 107.0 msft and 1036.3258056640625 cash
# sold MSFT, have 103.0 aapl and 106.0 msft and 1070.7490234375 cash
# sold MSFT, have 103.0 aapl and 105.0 msft and 1104.8861083984375 cash
# bought AAPL, have 104.0 aapl and 105.0 msft and 1079.1529541015625 cash
# sold MSFT, have 104.0 aapl and 104.0 msft and 1113.149658203125 cash
# sold AAPL, have 103.0 aapl and 104.0 msft and 1137.8115234375 cash
# sold AAPL, have 102.0 aapl and 104.0 msft and 1162.0020751953125 cash
# bought MSFT, have 102.0 aapl and 105.0 msft and 1119.6517333984375 cash
# nothing, have 102.0 aapl and 105.0 msft and 1119.6517333984375 cash
# bought MSFT, have 102.0 aapl and 106.0 msft and 1077.241943359375 cash
# sold MSFT, have 102.0 aapl and 105.0 msft and 1111.4755859375 cash
# nothing, have 102.0 aapl and 105.0 msft and 1111.4755859375 cash
# nothing, have 102.0 aapl and 105.0 msft and 1111.4755859375 cash
# bought AAPL, have 103.0 aapl and 105.0 msft and 1083.3551025390625 cash
# bought AAPL, have 104.0 aapl and 105.0 msft and 1057.078857421875 cash
# nothing, have 104.0 aapl and 105.0 msft and 1057.078857421875 cash
# bought MSFT, have 104.0 aapl and 106.0 msft and 1013.8175048828125 cash
# bought AAPL, have 105.0 aapl and 106.0 msft and 982.1665649414062 cash
# bought AAPL, have 106.0 aapl and 106.0 msft and 946.990234375 cash
# bought AAPL, have 107.0 aapl and 106.0 msft and 910.6881103515625 cash
# bought MSFT, have 107.0 aapl and 107.0 msft and 868.5068359375 cash
# sold AAPL, have 106.0 aapl and 107.0 msft and 896.0020751953125 cash
# nothing, have 106.0 aapl and 107.0 msft and 896.0020751953125 cash
# sold AAPL, have 105.0 aapl and 107.0 msft and 928.0266723632812 cash
# nothing, have 105.0 aapl and 107.0 msft and 928.0266723632812 cash
# bought AAPL, have 106.0 aapl and 107.0 msft and 883.9718627929688 cash
# nothing, have 106.0 aapl and 107.0 msft and 883.9718627929688 cash
# sold AAPL, have 105.0 aapl and 107.0 msft and 916.9114990234375 cash
# sold AAPL, have 104.0 aapl and 107.0 msft and 948.2625122070312 cash
# bought AAPL, have 105.0 aapl and 107.0 msft and 906.4136962890625 cash
# sold MSFT, have 105.0 aapl and 106.0 msft and 941.3399658203125 cash
# sold MSFT, have 105.0 aapl and 105.0 msft and 976.4210205078125 cash
# nothing, have 105.0 aapl and 105.0 msft and 976.4210205078125 cash
# nothing, have 105.0 aapl and 105.0 msft and 976.4210205078125 cash
# sold AAPL, have 104.0 aapl and 105.0 msft and 1012.3434448242188 cash
# sold AAPL, have 103.0 aapl and 105.0 msft and 1045.8402099609375 cash
# bought MSFT, have 103.0 aapl and 106.0 msft and 1003.1611938476562 cash
# sold MSFT, have 103.0 aapl and 105.0 msft and 1039.6302490234375 cash
# sold AAPL, have 102.0 aapl and 105.0 msft and 1077.34326171875 cash
# bought MSFT, have 102.0 aapl and 106.0 msft and 1033.3704833984375 cash
# sold AAPL, have 101.0 aapl and 106.0 msft and 1069.2742919921875 cash
# sold AAPL, have 100.0 aapl and 106.0 msft and 1104.16552734375 cash
# bought MSFT, have 100.0 aapl and 107.0 msft and 1058.97607421875 cash
# nothing, have 100.0 aapl and 107.0 msft and 1058.97607421875 cash
# sold AAPL, have 99.0 aapl and 107.0 msft and 1093.5654296875 cash
# bought AAPL, have 100.0 aapl and 107.0 msft and 1050.7891845703125 cash
# nothing, have 100.0 aapl and 107.0 msft and 1050.7891845703125 cash
# bought AAPL, have 101.0 aapl and 107.0 msft and 1007.4081420898438 cash
# sold MSFT, have 101.0 aapl and 106.0 msft and 1040.42333984375 cash
# bought AAPL, have 102.0 aapl and 106.0 msft and 992.4005737304688 cash
# bought AAPL, have 103.0 aapl and 106.0 msft and 942.7345581054688 cash
# nothing, have 103.0 aapl and 106.0 msft and 942.7345581054688 cash
# sold AAPL, have 102.0 aapl and 106.0 msft and 984.424072265625 cash
# bought AAPL, have 103.0 aapl and 106.0 msft and 927.6567993164062 cash
# nothing, have 103.0 aapl and 106.0 msft and 927.6567993164062 cash
# sold AAPL, have 102.0 aapl and 106.0 msft and 978.0895385742188 cash
# bought AAPL, have 103.0 aapl and 106.0 msft and 920.6131591796875 cash
# nothing, have 103.0 aapl and 106.0 msft and 920.6131591796875 cash
# sold AAPL, have 102.0 aapl and 106.0 msft and 958.6660766601562 cash
# nothing, have 102.0 aapl and 106.0 msft and 958.6660766601562 cash
# sold AAPL, have 101.0 aapl and 106.0 msft and 1002.8837890625 cash
# sold AAPL, have 100.0 aapl and 106.0 msft and 1041.8948974609375 cash
# sold MSFT, have 100.0 aapl and 105.0 msft and 1076.7625732421875 cash
# sold MSFT, have 100.0 aapl and 104.0 msft and 1110.2191162109375 cash
# sold AAPL, have 99.0 aapl and 104.0 msft and 1150.2333984375 cash
# sold AAPL, have 98.0 aapl and 104.0 msft and 1196.61962890625 cash
# bought MSFT, have 98.0 aapl and 105.0 msft and 1161.3646240234375 cash
# sold MSFT, have 98.0 aapl and 104.0 msft and 1190.5985107421875 cash
# bought AAPL, have 99.0 aapl and 104.0 msft and 1124.224609375 cash
# bought MSFT, have 99.0 aapl and 105.0 msft and 1087.4888916015625 cash
# bought MSFT, have 99.0 aapl and 106.0 msft and 1050.4208984375 cash
# bought AAPL, have 100.0 aapl and 106.0 msft and 982.9859008789062 cash
# nothing, have 100.0 aapl and 106.0 msft and 982.9859008789062 cash
# sold MSFT, have 100.0 aapl and 105.0 msft and 1010.5657348632812 cash
# bought AAPL, have 101.0 aapl and 105.0 msft and 945.0066528320312 cash
# nothing, have 101.0 aapl and 105.0 msft and 945.0066528320312 cash
# nothing, have 101.0 aapl and 105.0 msft and 945.0066528320312 cash
# nothing, have 101.0 aapl and 105.0 msft and 945.0066528320312 cash
# sold MSFT, have 101.0 aapl and 104.0 msft and 972.0826416015625 cash
# nothing, have 101.0 aapl and 104.0 msft and 972.0826416015625 cash
# bought AAPL, have 102.0 aapl and 104.0 msft and 905.9412841796875 cash
# /Users/joe/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# sold AAPL, have 101.0 aapl and 104.0 msft and 957.1093139648438 cash
# nothing, have 101.0 aapl and 104.0 msft and 957.1093139648438 cash
# nothing, have 101.0 aapl and 104.0 msft and 957.1093139648438 cash
# bought MSFT, have 101.0 aapl and 105.0 msft and 918.39306640625 cash
# sold AAPL, have 100.0 aapl and 105.0 msft and 972.2246704101562 cash
# nothing, have 100.0 aapl and 105.0 msft and 972.2246704101562 cash
# nothing, have 100.0 aapl and 105.0 msft and 972.2246704101562 cash
# bought MSFT, have 100.0 aapl and 106.0 msft and 936.7005004882812 cash
# sold MSFT, have 100.0 aapl and 105.0 msft and 965.2095947265625 cash
# nothing, have 100.0 aapl and 105.0 msft and 965.2095947265625 cash
# bought MSFT, have 100.0 aapl and 106.0 msft and 930.4266967773438 cash
# sold AAPL, have 99.0 aapl and 106.0 msft and 977.80908203125 cash
# sold AAPL, have 98.0 aapl and 106.0 msft and 1022.6128540039062 cash
# bought MSFT, have 98.0 aapl and 107.0 msft and 988.38427734375 cash
# bought MSFT, have 98.0 aapl and 108.0 msft and 953.1414794921875 cash
# bought MSFT, have 98.0 aapl and 109.0 msft and 919.0184326171875 cash
# nothing, have 98.0 aapl and 109.0 msft and 919.0184326171875 cash
# bought MSFT, have 98.0 aapl and 110.0 msft and 883.3399047851562 cash
# nothing, have 98.0 aapl and 110.0 msft and 883.3399047851562 cash
# bought MSFT, have 98.0 aapl and 111.0 msft and 849.0099487304688 cash
# nothing, have 98.0 aapl and 111.0 msft and 849.0099487304688 cash
# bought MSFT, have 98.0 aapl and 112.0 msft and 818.7785034179688 cash
# nothing, have 98.0 aapl and 112.0 msft and 818.7785034179688 cash
# sold AAPL, have 97.0 aapl and 112.0 msft and 848.5376586914062 cash
# sold AAPL, have 96.0 aapl and 112.0 msft and 883.4221801757812 cash
# sold MSFT, have 96.0 aapl and 111.0 msft and 907.435302734375 cash
# bought AAPL, have 97.0 aapl and 111.0 msft and 868.06591796875 cash
# nothing, have 97.0 aapl and 111.0 msft and 868.06591796875 cash
# sold AAPL, have 96.0 aapl and 111.0 msft and 896.4700317382812 cash
# bought AAPL, have 97.0 aapl and 111.0 msft and 860.8574829101562 cash
# bought AAPL, have 98.0 aapl and 111.0 msft and 825.5036010742188 cash
# nothing, have 98.0 aapl and 111.0 msft and 825.5036010742188 cash
# bought AAPL, have 99.0 aapl and 111.0 msft and 780.1619262695312 cash
# sold AAPL, have 98.0 aapl and 111.0 msft and 817.7770385742188 cash
# nothing, have 98.0 aapl and 111.0 msft and 817.7770385742188 cash
# nothing, have 98.0 aapl and 111.0 msft and 817.7770385742188 cash
# bought MSFT, have 98.0 aapl and 112.0 msft and 778.6240844726562 cash
# bought AAPL, have 99.0 aapl and 112.0 msft and 738.1505737304688 cash
# bought MSFT, have 99.0 aapl and 113.0 msft and 699.5321655273438 cash
# bought AAPL, have 100.0 aapl and 113.0 msft and 661.8309326171875 cash
# nothing, have 100.0 aapl and 113.0 msft and 661.8309326171875 cash
# sold MSFT, have 100.0 aapl and 112.0 msft and 693.7302856445312 cash
# sold MSFT, have 100.0 aapl and 111.0 msft and 726.6394653320312 cash
# nothing, have 100.0 aapl and 111.0 msft and 726.6394653320312 cash
# bought MSFT, have 100.0 aapl and 112.0 msft and 690.9666748046875 cash
# bought AAPL, have 101.0 aapl and 112.0 msft and 676.97119140625 cash
# bought MSFT, have 101.0 aapl and 113.0 msft and 642.89990234375 cash
# sold MSFT, have 101.0 aapl and 112.0 msft and 671.021240234375 cash
# bought AAPL, have 102.0 aapl and 112.0 msft and 659.28662109375 cash
# bought MSFT, have 102.0 aapl and 113.0 msft and 628.431640625 cash
# bought MSFT, have 102.0 aapl and 114.0 msft and 595.7044067382812 cash
# sold AAPL, have 101.0 aapl and 114.0 msft and 605.7146606445312 cash
# bought AAPL, have 102.0 aapl and 114.0 msft and 592.8145751953125 cash
# bought AAPL, have 103.0 aapl and 114.0 msft and 576.5100708007812 cash
# bought AAPL, have 104.0 aapl and 114.0 msft and 559.7161865234375 cash
# bought AAPL, have 105.0 aapl and 114.0 msft and 540.3209838867188 cash
# nothing, have 105.0 aapl and 114.0 msft and 540.3209838867188 cash
# nothing, have 105.0 aapl and 114.0 msft and 540.3209838867188 cash
# bought AAPL, have 106.0 aapl and 114.0 msft and 516.5646362304688 cash
# sold MSFT, have 106.0 aapl and 113.0 msft and 545.472900390625 cash
# sold MSFT, have 106.0 aapl and 112.0 msft and 574.4459838867188 cash
# bought MSFT, have 106.0 aapl and 113.0 msft and 537.5692138671875 cash
# nothing, have 106.0 aapl and 113.0 msft and 537.5692138671875 cash
# bought MSFT, have 106.0 aapl and 114.0 msft and 509.0919494628906 cash
# sold AAPL, have 105.0 aapl and 114.0 msft and 513.6873168945312 cash
# sold AAPL, have 104.0 aapl and 114.0 msft and 517.55810546875 cash
# bought MSFT, have 104.0 aapl and 115.0 msft and 487.0611572265625 cash
# nothing, have 104.0 aapl and 115.0 msft and 487.0611572265625 cash
# nothing, have 104.0 aapl and 115.0 msft and 487.0611572265625 cash
# sold AAPL, have 103.0 aapl and 115.0 msft and 493.7845153808594 cash
# sold MSFT, have 103.0 aapl and 114.0 msft and 518.347900390625 cash
# sold AAPL, have 102.0 aapl and 114.0 msft and 524.5850830078125 cash
# sold AAPL, have 101.0 aapl and 114.0 msft and 527.9736328125 cash
# sold AAPL, have 100.0 aapl and 114.0 msft and 529.3595581054688 cash
# bought AAPL, have 101.0 aapl and 114.0 msft and 525.240234375 cash
# bought AAPL, have 102.0 aapl and 114.0 msft and 520.3345336914062 cash
# sold AAPL, have 101.0 aapl and 114.0 msft and 524.9016723632812 cash
# bought AAPL, have 102.0 aapl and 114.0 msft and 516.76220703125 cash
# nothing, have 102.0 aapl and 114.0 msft and 516.76220703125 cash
# sold MSFT, have 102.0 aapl and 113.0 msft and 544.0240478515625 cash
# bought MSFT, have 102.0 aapl and 114.0 msft and 509.74481201171875 cash
# nothing, have 102.0 aapl and 114.0 msft and 509.74481201171875 cash
# sold AAPL, have 101.0 aapl and 114.0 msft and 523.3113403320312 cash
# nothing, have 101.0 aapl and 114.0 msft and 523.3113403320312 cash
# bought MSFT, have 101.0 aapl and 115.0 msft and 489.232177734375 cash
# bought AAPL, have 102.0 aapl and 115.0 msft and 475.1317443847656 cash
# sold AAPL, have 101.0 aapl and 115.0 msft and 483.6578369140625 cash
# nothing, have 101.0 aapl and 115.0 msft and 483.6578369140625 cash
# bought AAPL, have 102.0 aapl and 115.0 msft and 463.7333068847656 cash
# sold AAPL, have 101.0 aapl and 115.0 msft and 479.01361083984375 cash
# sold AAPL, have 100.0 aapl and 115.0 msft and 493.77630615234375 cash
# bought AAPL, have 101.0 aapl and 115.0 msft and 474.2866516113281 cash
# bought AAPL, have 102.0 aapl and 115.0 msft and 452.38262939453125 cash
# sold AAPL, have 101.0 aapl and 115.0 msft and 470.4615173339844 cash
# bought MSFT, have 101.0 aapl and 116.0 msft and 435.40301513671875 cash
# sold AAPL, have 100.0 aapl and 116.0 msft and 449.72869873046875 cash
# sold MSFT, have 100.0 aapl and 115.0 msft and 476.1125793457031 cash
# sold AAPL, have 99.0 aapl and 115.0 msft and 487.62103271484375 cash
# sold AAPL, have 98.0 aapl and 115.0 msft and 494.9219055175781 cash
# sold MSFT, have 98.0 aapl and 114.0 msft and 522.9222412109375 cash
# bought MSFT, have 98.0 aapl and 115.0 msft and 489.25836181640625 cash
# nothing, have 98.0 aapl and 115.0 msft and 489.25836181640625 cash
# sold MSFT, have 98.0 aapl and 114.0 msft and 516.9581909179688 cash
# bought AAPL, have 99.0 aapl and 114.0 msft and 500.0550537109375 cash
# sold AAPL, have 98.0 aapl and 114.0 msft and 514.9063110351562 cash
# sold AAPL, have 97.0 aapl and 114.0 msft and 530.14892578125 cash
# sold AAPL, have 96.0 aapl and 114.0 msft and 543.6319580078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 543.6319580078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 543.6319580078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 543.6319580078125 cash
# bought AAPL, have 97.0 aapl and 114.0 msft and 521.4882202148438 cash
# sold AAPL, have 96.0 aapl and 114.0 msft and 544.6007080078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 544.6007080078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 544.6007080078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 544.6007080078125 cash
# nothing, have 96.0 aapl and 114.0 msft and 544.6007080078125 cash
# sold AAPL, have 95.0 aapl and 114.0 msft and 576.1547241210938 cash
# sold AAPL, have 94.0 aapl and 114.0 msft and 607.4161376953125 cash
# bought AAPL, have 95.0 aapl and 114.0 msft and 568.784423828125 cash
# bought AAPL, have 96.0 aapl and 114.0 msft and 527.496337890625 cash
# sold MSFT, have 96.0 aapl and 113.0 msft and 555.4180908203125 cash
# sold MSFT, have 96.0 aapl and 112.0 msft and 584.09765625 cash
# sold AAPL, have 95.0 aapl and 112.0 msft and 619.071044921875 cash
# nothing, have 95.0 aapl and 112.0 msft and 619.071044921875 cash
# sold AAPL, have 94.0 aapl and 112.0 msft and 651.3621826171875 cash
# nothing, have 94.0 aapl and 112.0 msft and 651.3621826171875 cash
# bought MSFT, have 94.0 aapl and 113.0 msft and 613.9552001953125 cash
# sold AAPL, have 93.0 aapl and 113.0 msft and 649.8685302734375 cash
# bought MSFT, have 93.0 aapl and 114.0 msft and 613.205078125 cash
# bought MSFT, have 93.0 aapl and 115.0 msft and 576.1544189453125 cash
# bought AAPL, have 94.0 aapl and 115.0 msft and 524.2471923828125 cash
# sold AAPL, have 93.0 aapl and 115.0 msft and 565.1281127929688 cash
# sold AAPL, have 92.0 aapl and 115.0 msft and 606.5804443359375 cash
# sold AAPL, have 91.0 aapl and 115.0 msft and 648.5411987304688 cash
# nothing, have 91.0 aapl and 115.0 msft and 648.5411987304688 cash
# bought AAPL, have 92.0 aapl and 115.0 msft and 608.5201416015625 cash
# nothing, have 92.0 aapl and 115.0 msft and 608.5201416015625 cash
# bought MSFT, have 92.0 aapl and 116.0 msft and 572.5516357421875 cash
# nothing, have 92.0 aapl and 116.0 msft and 572.5516357421875 cash
# nothing, have 92.0 aapl and 116.0 msft and 572.5516357421875 cash
# nothing, have 92.0 aapl and 116.0 msft and 572.5516357421875 cash
# sold AAPL, have 91.0 aapl and 116.0 msft and 610.8035278320312 cash
# sold MSFT, have 91.0 aapl and 115.0 msft and 642.824462890625 cash
# nothing, have 91.0 aapl and 115.0 msft and 642.824462890625 cash
# nothing, have 91.0 aapl and 115.0 msft and 642.824462890625 cash
# nothing, have 91.0 aapl and 115.0 msft and 642.824462890625 cash
# bought AAPL, have 92.0 aapl and 115.0 msft and 589.852294921875 cash
# nothing, have 92.0 aapl and 115.0 msft and 589.852294921875 cash
# bought MSFT, have 92.0 aapl and 116.0 msft and 551.626220703125 cash
# nothing, have 92.0 aapl and 116.0 msft and 551.626220703125 cash
# nothing, have 92.0 aapl and 116.0 msft and 551.626220703125 cash
# bought MSFT, have 92.0 aapl and 117.0 msft and 512.0404052734375 cash
# sold MSFT, have 92.0 aapl and 116.0 msft and 542.8646240234375 cash
# nothing, have 92.0 aapl and 116.0 msft and 542.8646240234375 cash
# sold MSFT, have 92.0 aapl and 115.0 msft and 575.5465087890625 cash
# bought AAPL, have 93.0 aapl and 115.0 msft and 528.1799926757812 cash
# nothing, have 93.0 aapl and 115.0 msft and 528.1799926757812 cash
# bought AAPL, have 94.0 aapl and 115.0 msft and 482.1777038574219 cash
# nothing, have 94.0 aapl and 115.0 msft and 482.1777038574219 cash
# sold AAPL, have 93.0 aapl and 115.0 msft and 534.3147583007812 cash
# nothing, have 93.0 aapl and 115.0 msft and 534.3147583007812 cash
# sold AAPL, have 92.0 aapl and 115.0 msft and 582.6806030273438 cash
# sold AAPL, have 91.0 aapl and 115.0 msft and 635.0738525390625 cash
# bought MSFT, have 91.0 aapl and 116.0 msft and 588.5972290039062 cash
# bought AAPL, have 92.0 aapl and 116.0 msft and 531.810302734375 cash
# sold MSFT, have 92.0 aapl and 115.0 msft and 571.1362915039062 cash
# sold MSFT, have 92.0 aapl and 114.0 msft and 611.9310913085938 cash
# done, have 92.0 aapl and 114.0 msft and 611.9310913085938 cash
# [tensor(92.), tensor(114.), tensor(611.9311), 51.613994277626006, 43.4816083631882, tensor(10381.0869), 56.67894610754449, 44.35905510281329] tensor(12384.2803)
# total portfolio value 10381.0869140625

# %%
apl_open_orig = apl_stock["Open"].values
apl_close_orig = apl_stock["Close"].values
msf_open_orig = msf_stock["Open"].values
msf_close_orig = msf_stock["Close"].values
apl_open_orig[:108] /= 7
apl_close_orig[:108] /= 7

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)
env.reset()
complete_game = False
while not complete_game:
    bought_apl_at = []
    bought_msf_at = []
    sold_apl_at = []
    sold_msf_at = []
    bought_apl_at_orig = []
    bought_msf_at_orig = []
    sold_apl_at_orig = []
    sold_msf_at_orig = []
    nothing_at = []
    ba_action_times = []
    bm_action_times = []
    sa_action_times = []
    sm_action_times = []
    n_action_times = []
    starting_val = env.starting_portfolio_value
    print("Starting portfolio value: {}".format(starting_val))
    for i in range(0,env.series_length + 1):
        action = model.act(env.state)
        if action == 0:
            bought_apl_at.append(apl_open[env.cur_timestep])
            bought_apl_at_orig.append(apl_open_orig[env.cur_timestep])
            ba_action_times.append(env.cur_timestep)
        if action == 1:
            sold_apl_at.append(apl_close[env.cur_timestep])
            sold_apl_at_orig.append(apl_close_orig[env.cur_timestep])
            sa_action_times.append(env.cur_timestep)
        if action == 2:
            nothing_at.append(35)
            n_action_times.append(env.cur_timestep)
        if action == 3:
            bought_msf_at.append(msf_open[env.cur_timestep])
            bought_msf_at_orig.append(msf_open_orig[env.cur_timestep])
            bm_action_times.append(env.cur_timestep)
        if action == 4:
            sold_msf_at.append(msf_close[env.cur_timestep])
            sold_msf_at_orig.append(msf_close_orig[env.cur_timestep])
            sm_action_times.append(env.cur_timestep)
        next_state, reward, done, msg = env.step(action)
        if msg["msg"] == 'bankrupted self':
            env.reset()
            break
        if msg["msg"] == 'sold more than have':
            env.reset()
            break
        if msg["msg"] == "done":
            print("{}, have {} aapl and {} msft and {} cash".format(msg["msg"], next_state[0], next_state[1], next_state[2]))
            val = env.portfolio_value()
            print("Finished portfolio value {}".format(val))
            if val > starting_val * 1.1: complete_game = True
            env.reset()
            break
# Out:
# Starting portfolio value: 7392.4580078125
# /Users/joe/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Starting portfolio value: 7674.998046875
# done, have 108.0 aapl and 98.0 msft and 80.77389526367188 cash
# Finished portfolio value 9989.5615234375

# %%
plt.figure(1, figsize=(14,5))
apl = plt.subplot(121)
msf = plt.subplot(122)
apl.plot(range(0, len(apl_open)), apl_open)
msf.plot(range(0, len(msf_open)), msf_open)
apl.plot(ba_action_times, bought_apl_at, "ro")
apl.plot(sa_action_times, sold_apl_at, "go")
apl.plot(n_action_times, nothing_at, "yx")
msf.plot(n_action_times, nothing_at, "yx")
msf.plot(bm_action_times, bought_msf_at, "ro")
msf.plot(sm_action_times, sold_msf_at, "go")

# %%
plt.figure(1, figsize=(14,5))
apl = plt.subplot(121)
msf = plt.subplot(122)
apl.plot(range(0, len(apl_open_orig)), apl_open_orig)
msf.plot(range(0, len(msf_open_orig)), msf_open_orig)
apl.plot(ba_action_times, bought_apl_at_orig, "ro")
apl.plot(sa_action_times, sold_apl_at_orig, "go")
apl.plot(n_action_times, nothing_at, "yx")
msf.plot(n_action_times, nothing_at, "yx")
msf.plot(bm_action_times, bought_msf_at_orig, "ro")
msf.plot(sm_action_times, sold_msf_at_orig, "go")
